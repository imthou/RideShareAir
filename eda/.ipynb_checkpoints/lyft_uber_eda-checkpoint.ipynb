# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns
# %matplotlib inline

# %%
lyft = pd.read_csv('../data/lyft_data.csv', parse_dates=['record_time'])
lyft.set_index('record_time', inplace=True)
lyft.index = lyft.index - pd.Timedelta(hours=7)
lyft['hour'] = lyft.index.hour
lyft['date'] = lyft.index.date
lyft['dayofweek'] = lyft.index.dayofweek
lyft['weekofyear'] = lyft.index.weekofyear
lyft = lyft.groupby(['date','hour','city','ride_type']).mean().reset_index()
lyft['record_time'] = pd.to_datetime(lyft['date'].astype(str) + ' ' + lyft['hour'].astype(str) + ":00:00")
lyft.set_index('record_time', inplace=True)
lyft.head()
# Out:
#                            date  hour     city  ride_type  \
# record_time
# 2016-04-06 21:00:00  2016-04-06    21  chicago       lyft
# 2016-04-06 21:00:00  2016-04-06    21  chicago  lyft_line
# 2016-04-06 21:00:00  2016-04-06    21  chicago  lyft_plus
# 2016-04-06 21:00:00  2016-04-06    21   denver       lyft
# 2016-04-06 21:00:00  2016-04-06    21   denver  lyft_line
#
#                      estimated_cost_cents_min  estimated_cost_cents_max  \
# record_time
# 2016-04-06 21:00:00               2915.289474               3945.947368
# 2016-04-06 21:00:00               2840.500000               2840.500000
# 2016-04-06 21:00:00               4097.552632               5544.973684
# 2016-04-06 21:00:00               3003.000000               4063.000000
# 2016-04-06 21:00:00               3201.000000               3201.000000
#
#                      estimated_distance_miles  estimated_duration_seconds  \
# record_time
# 2016-04-06 21:00:00                     19.26                      2204.0
# 2016-04-06 21:00:00                     19.26                      2204.0
# 2016-04-06 21:00:00                     19.26                      2204.0
# 2016-04-06 21:00:00                     26.07                      2200.0
# 2016-04-06 21:00:00                     26.07                      2200.0
#
#                      eta_seconds  base_charge     ...      \
# record_time                                       ...
# 2016-04-06 21:00:00   132.631579        171.0     ...
# 2016-04-06 21:00:00   131.052632        171.0     ...
# 2016-04-06 21:00:00   290.184211        256.0     ...
# 2016-04-06 21:00:00   101.052632         50.0     ...
# 2016-04-06 21:00:00   101.052632          NaN     ...
#
#                      cancel_penalty_amount  num_drivers  seats  \
# record_time
# 2016-04-06 21:00:00                  500.0          8.0    4.0
# 2016-04-06 21:00:00                  500.0          8.0    2.0
# 2016-04-06 21:00:00                  500.0          8.0    6.0
# 2016-04-06 21:00:00                  500.0          8.0    4.0
# 2016-04-06 21:00:00                    NaN          8.0    NaN
#
#                      trust_and_service  start_latitude  start_longitude  \
# record_time
# 2016-04-06 21:00:00              160.0       41.877688       -87.630413
# 2016-04-06 21:00:00              160.0       41.877688       -87.630413
# 2016-04-06 21:00:00              160.0       41.877688       -87.630413
# 2016-04-06 21:00:00              195.0       39.740782      -104.991153
# 2016-04-06 21:00:00                NaN       39.740782      -104.991153
#
#                      stop_latitude  stop_longitude  dayofweek  weekofyear
# record_time
# 2016-04-06 21:00:00      41.973551      -87.909057          2          14
# 2016-04-06 21:00:00      41.973551      -87.909057          2          14
# 2016-04-06 21:00:00      41.973551      -87.909057          2          14
# 2016-04-06 21:00:00      39.851727     -104.673804          2          14
# 2016-04-06 21:00:00      39.851727     -104.673804          2          14
#
# [5 rows x 23 columns]

# %%
uber = pd.read_csv('../data/organized_uber_41416.csv', parse_dates=['record_time'])
uber.set_index('record_time', inplace=True)
uber.index = uber.index - pd.Timedelta(hours=7)
uber['hour'] = uber.index.hour
uber['date'] = uber.index.date
uber['dayofweek'] = uber.index.dayofweek
uber['weekofyear'] = uber.index.weekofyear
uber = uber.groupby(['date','hour','city','display_name']).mean().reset_index()
uber['record_time'] = pd.to_datetime(uber['date'].astype(str) + ' ' + uber['hour'].astype(str) + ":00:00")
uber.set_index('record_time', inplace=True)
uber.head()
# Out:
#                            date  hour     city display_name  low_estimate  \
# record_time
# 2016-02-15 08:00:00  2016-02-15     8  chicago    uberBLACK          68.0
# 2016-02-15 08:00:00  2016-02-15     8  chicago  uberESPANOL          26.0
# 2016-02-15 08:00:00  2016-02-15     8  chicago   uberSELECT          49.0
# 2016-02-15 08:00:00  2016-02-15     8  chicago      uberSUV          87.0
# 2016-02-15 08:00:00  2016-02-15     8  chicago     uberTAXI           NaN
#
#                      avg_price_est  high_estimate  trip_duration  \
# record_time
# 2016-02-15 08:00:00           78.5           89.0         1920.0
# 2016-02-15 08:00:00           30.0           34.0         1920.0
# 2016-02-15 08:00:00           55.5           62.0         1920.0
# 2016-02-15 08:00:00           99.5          112.0         1920.0
# 2016-02-15 08:00:00            NaN            NaN         1920.0
#
#                      trip_distance  surge_multiplier     ...      \
# record_time                                              ...
# 2016-02-15 08:00:00          15.78               1.0     ...
# 2016-02-15 08:00:00          15.78               1.0     ...
# 2016-02-15 08:00:00          15.78               1.0     ...
# 2016-02-15 08:00:00          15.78               1.0     ...
# 2016-02-15 08:00:00          15.78               1.0     ...
#
#                      cost_per_minute  cost_per_distance  cancellation_fee  \
# record_time
# 2016-02-15 08:00:00             0.40               3.50              10.0
# 2016-02-15 08:00:00             0.20               0.90               5.0
# 2016-02-15 08:00:00             0.35               2.00               5.0
# 2016-02-15 08:00:00             0.55               4.05              10.0
# 2016-02-15 08:00:00              NaN                NaN               NaN
#
#                      service_fees  start_latitude  start_longitude  \
# record_time
# 2016-02-15 08:00:00           0.0       41.877688       -87.630413
# 2016-02-15 08:00:00           1.2       41.877688       -87.630413
# 2016-02-15 08:00:00           1.2       41.877688       -87.630413
# 2016-02-15 08:00:00           0.0       41.877688       -87.630413
# 2016-02-15 08:00:00           0.0       41.877688       -87.630413
#
#                      stop_latitude  stop_longitude  dayofweek  weekofyear
# record_time
# 2016-02-15 08:00:00      41.973551      -87.909057          0           7
# 2016-02-15 08:00:00      41.973551      -87.909057          0           7
# 2016-02-15 08:00:00      41.973551      -87.909057          0           7
# 2016-02-15 08:00:00      41.973551      -87.909057          0           7
# 2016-02-15 08:00:00      41.973551      -87.909057          0           7
#
# [5 rows x 25 columns]

# %%
lyft.describe()
# Out:
#               hour  estimated_cost_cents_min  estimated_cost_cents_max  \
# count  2790.000000               2790.000000               2790.000000
# mean     11.306452               4003.438225               5032.639770
# std       6.941671               1700.891802               2446.184368
# min       0.000000               1848.000000               1848.000000
# 25%       5.000000               2780.000000               3178.067241
# 50%      11.000000               3550.666667               4523.551724
# 75%      17.000000               4677.400000               6107.785345
# max      23.000000              13651.034483              18470.068966
#
#        estimated_distance_miles  estimated_duration_seconds  eta_seconds  \
# count               2790.000000                 2790.000000  2790.000000
# mean                  18.034000                 1929.400000   170.751212
# std                    4.652967                  461.505124   118.235552
# min                   13.150000                 1353.000000    60.000000
# 25%                   13.760000                 1405.000000    93.103448
# 50%                   17.930000                 2200.000000   133.089983
# 75%                   19.260000                 2204.000000   206.896552
# max                   26.070000                 2485.000000  1153.052632
#
#        base_charge  cost_minimum  cost_per_mile  cost_per_minute  \
# count  2577.000000   2577.000000    2577.000000      2577.000000
# mean    217.781529    564.712844     159.291036        27.575475
# std      82.802405    237.417350      63.659547         9.250390
# min      50.000000    300.000000      90.000000         9.000000
# 25%     171.000000    400.000000     115.000000        22.000000
# 50%     250.000000    500.000000     137.000000        30.000000
# 75%     300.000000    700.000000     185.000000        33.000000
# max     350.000000   1200.000000     297.000000        50.000000
#
#        cancel_penalty_amount  num_drivers        seats  trust_and_service  \
# count            2577.000000  2790.000000  2577.000000        2577.000000
# mean              572.176950     7.447242     4.165308         136.536671
# std               175.758215     1.378910     1.590634          73.684674
# min               500.000000     0.586207     2.000000           0.000000
# 25%               500.000000     7.965517     2.000000         155.000000
# 50%               500.000000     8.000000     4.000000         160.000000
# 75%               500.000000     8.000000     6.000000         195.000000
# max              1000.000000     8.000000     6.000000         195.000000
#
#        start_latitude  start_longitude  stop_latitude  stop_longitude  \
# count     2790.000000      2790.000000    2790.000000     2790.000000
# mean        41.552000      -102.271830      41.507372     -102.210958
# std          3.314615        19.136319       3.292060       19.132339
# min         37.776422      -122.418389      37.616720     -122.389393
# 25%         39.740782      -122.334654      39.851727     -122.300536
# 50%         40.759652      -104.991153      40.643800     -104.673804
# 75%         41.877688       -87.630413      41.973551      -87.909057
# max         47.605454       -73.984542      47.451062      -73.782000
#
#          dayofweek   weekofyear
# count  2790.000000  2790.000000
# mean      2.983871    14.467742
# std       1.905275     0.499048
# min       0.000000    14.000000
# 25%       1.000000    14.000000
# 50%       3.000000    14.000000
# 75%       5.000000    15.000000
# max       6.000000    15.000000

# %%
lyft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2790 entries, 2016-04-06 21:00:00 to 2016-04-14 14:00:00
# Data columns (total 23 columns):
# date                          2790 non-null object
# hour                          2790 non-null int64
# city                          2790 non-null object
# ride_type                     2790 non-null object
# estimated_cost_cents_min      2790 non-null float64
# estimated_cost_cents_max      2790 non-null float64
# estimated_distance_miles      2790 non-null float64
# estimated_duration_seconds    2790 non-null float64
# eta_seconds                   2790 non-null float64
# base_charge                   2577 non-null float64
# cost_minimum                  2577 non-null float64
# cost_per_mile                 2577 non-null float64
# cost_per_minute               2577 non-null float64
# cancel_penalty_amount         2577 non-null float64
# num_drivers                   2790 non-null float64
# seats                         2577 non-null float64
# trust_and_service             2577 non-null float64
# start_latitude                2790 non-null float64
# start_longitude               2790 non-null float64
# stop_latitude                 2790 non-null float64
# stop_longitude                2790 non-null float64
# dayofweek                     2790 non-null int32
# weekofyear                    2790 non-null int32
# dtypes: float64(17), int32(2), int64(1), object(3)
# memory usage: 501.3+ KB

# %%
lyft[lyft.columns[:10]].head()
# Out:
#                            date  hour     city  ride_type  \
# record_time
# 2016-04-06 21:00:00  2016-04-06    21  chicago       lyft
# 2016-04-06 21:00:00  2016-04-06    21  chicago  lyft_line
# 2016-04-06 21:00:00  2016-04-06    21  chicago  lyft_plus
# 2016-04-06 21:00:00  2016-04-06    21   denver       lyft
# 2016-04-06 21:00:00  2016-04-06    21   denver  lyft_line
#
#                      estimated_cost_cents_min  estimated_cost_cents_max  \
# record_time
# 2016-04-06 21:00:00               2915.289474               3945.947368
# 2016-04-06 21:00:00               2840.500000               2840.500000
# 2016-04-06 21:00:00               4097.552632               5544.973684
# 2016-04-06 21:00:00               3003.000000               4063.000000
# 2016-04-06 21:00:00               3201.000000               3201.000000
#
#                      estimated_distance_miles  estimated_duration_seconds  \
# record_time
# 2016-04-06 21:00:00                     19.26                      2204.0
# 2016-04-06 21:00:00                     19.26                      2204.0
# 2016-04-06 21:00:00                     19.26                      2204.0
# 2016-04-06 21:00:00                     26.07                      2200.0
# 2016-04-06 21:00:00                     26.07                      2200.0
#
#                      eta_seconds  base_charge
# record_time
# 2016-04-06 21:00:00   132.631579        171.0
# 2016-04-06 21:00:00   131.052632        171.0
# 2016-04-06 21:00:00   290.184211        256.0
# 2016-04-06 21:00:00   101.052632         50.0
# 2016-04-06 21:00:00   101.052632          NaN

# %%
lyft[lyft.columns[10:19]].head()
# Out:
#                      cost_minimum  cost_per_mile  cost_per_minute  \
# record_time
# 2016-04-06 21:00:00         300.0           90.0             22.0
# 2016-04-06 21:00:00         300.0           90.0             22.0
# 2016-04-06 21:00:00         400.0          135.0             33.0
# 2016-04-06 21:00:00         400.0          101.0             12.0
# 2016-04-06 21:00:00           NaN            NaN              NaN
#
#                      cancel_penalty_amount  num_drivers  seats  \
# record_time
# 2016-04-06 21:00:00                  500.0          8.0    4.0
# 2016-04-06 21:00:00                  500.0          8.0    2.0
# 2016-04-06 21:00:00                  500.0          8.0    6.0
# 2016-04-06 21:00:00                  500.0          8.0    4.0
# 2016-04-06 21:00:00                    NaN          8.0    NaN
#
#                      trust_and_service  start_latitude  start_longitude
# record_time
# 2016-04-06 21:00:00              160.0       41.877688       -87.630413
# 2016-04-06 21:00:00              160.0       41.877688       -87.630413
# 2016-04-06 21:00:00              160.0       41.877688       -87.630413
# 2016-04-06 21:00:00              195.0       39.740782      -104.991153
# 2016-04-06 21:00:00                NaN       39.740782      -104.991153

# %%
lyft[lyft.columns[20:]].head()
# Out:
#                      stop_longitude  dayofweek  weekofyear
# record_time
# 2016-04-06 21:00:00      -87.909057          2          14
# 2016-04-06 21:00:00      -87.909057          2          14
# 2016-04-06 21:00:00      -87.909057          2          14
# 2016-04-06 21:00:00     -104.673804          2          14
# 2016-04-06 21:00:00     -104.673804          2          14

# %%
lyft['ride_type'].unique()
# Out:
# array(['lyft', 'lyft_line', 'lyft_plus'], dtype=object)

# %%
lyft['avg_est_price'] = (lyft['estimated_cost_cents_max'] + lyft['estimated_cost_cents_min']) / 200.
lyft['avg_est_price'].head()
# Out:
# record_time
# 2016-04-06 21:00:00    34.306184
# 2016-04-06 21:00:00    28.405000
# 2016-04-06 21:00:00    48.212632
# 2016-04-06 21:00:00    35.330000
# 2016-04-06 21:00:00    32.010000
# Name: avg_est_price, dtype: float64

# %%
cities = lyft['city'].unique().tolist()
ridetypes = lyft['ride_type'].unique().tolist()
fig, ax = plt.subplots(5,1, figsize=(20,30))
d = lyft.query("ride_type == 'lyft_line' and city == 'denver'")['avg_est_price']
dates = np.unique(d.index.date)
for i, axs in enumerate(ax.reshape(5,)):
    for ridetype in ridetypes:
        data = lyft.query("ride_type == @ridetype and city == @cities[@i]")['avg_est_price']
        axs.plot(data, label=ridetype)
    axs.set_title(cities[i])
    axs.set_ylabel('average ride price')
    axs.set_xlabel('day')
    axs.set_xticks(dates)
    axs.set_xticklabels(dates, rotation='45')
    axs.legend(loc='upper right')
plt.tight_layout()

# %%
start_date = str(lyft.index[0])
end_date = str(lyft.index[-1])
ly = lyft.ix[start_date:end_date]
ub = uber.ix[start_date:end_date]

# %%
a = np.array([True,False,True,False])
np.insert(a, 1, False)
# Out:
# array([ True, False, False,  True, False], dtype=bool)

# %%
from matplotlib.dates import MonthLocator, WeekdayLocator, DateFormatter, HourLocator

cities = ly['city'].unique().tolist()
fig, ax = plt.subplots(5,1, figsize=(20,30))

ly_d = ly.query("ride_type == 'lyft' and city == 'denver'")['avg_est_price']
ub_d = ub.query("display_name == 'uberX' and city == 'denver'")['avg_price_est']

dates = np.unique(ly_d.index.date)
for i, axs in enumerate(ax.reshape(5,)):
#     axs.set_axis_bgcolor('lightgray')
    ly_data = ly.query("ride_type == 'lyft' and city == @cities[@i]")['avg_est_price']
    axs.plot_date(ly_data.index.to_pydatetime(), ly_data.values, 'o-', label='lyft', color='r')

    ub_data = ub.query("display_name == 'uberX' and city == @cities[@i]")['avg_price_est']
    axs.plot_date(ub_data.index.to_pydatetime(), ub_data.values, 'o-', label='uberX', color='k')
    
    maxy = max([ly_data.max()*1.1,ub_data.max()*1.1])
    diff = ub_data - ly_data
    axs.fill_between(ly_data.index, 0, maxy, where=diff >= 0.0 , alpha=0.2, label='take lyft', color='r')
#     axs.fill_between(ub_data.index, 0, maxs, where=diff < 0.0, alpha=0.2, label='take uber', color='k')
    
    axs.xaxis.set_minor_locator(HourLocator(byhour=range(24), interval=4))
    axs.xaxis.set_minor_formatter(DateFormatter('%H'))
    axs.xaxis.set_major_locator(WeekdayLocator(byweekday=range(7), interval=1))
    axs.xaxis.set_major_formatter(DateFormatter('\n\n%a\n%D'))
    axs.set_title(cities[i])
    axs.set_ylabel('average ride price')
    axs.set_xlabel('day')
    axs.legend(loc='upper right')
#     axs.grid([])
    axs.set_ylim([0,maxy])
    
plt.tight_layout()

# %%
### make a histogram of price differences
cities = ly['city'].unique().tolist()
fig, ax = plt.subplots(5,1, figsize=(20,30))

for i, axs in enumerate(ax.reshape(5,)):
    ly_data = ly.query("ride_type == 'lyft' and city == @cities[@i]")['avg_est_price']
    ub_data = ub.query("display_name == 'uberX' and city == @cities[@i]")['avg_price_est']
    diff = ub_data - ly_data
    pos = diff > 0.0
    neg = diff < 0.0
    axs.bar(diff[pos].index.to_pydatetime(), diff[pos].values, width=0.03, color='r', label="take lyft")
    axs.bar(diff[neg].index.to_pydatetime(), diff[neg].values, width=0.03, color='k', label="take uber")
    axs.xaxis.set_minor_locator(HourLocator(byhour=range(24), interval=4))
    axs.xaxis.set_minor_formatter(DateFormatter('%H'))
    axs.xaxis.set_major_locator(WeekdayLocator(byweekday=range(7), interval=1))
    axs.xaxis.set_major_formatter(DateFormatter('\n\n%a\n%D'))
    axs.set_title(cities[i])
    axs.set_ylabel('Average Price Difference')
    axs.set_xlabel('Time')
    axs.legend(loc='upper right')
plt.tight_layout()

# %%
cities = ly['city'].unique().tolist()
fig, axs = plt.subplots(figsize=(20,8))

ly_data = ly.query("ride_type == 'lyft' and city == @cities[1]")['avg_est_price']
ub_data = ub.query("display_name == 'uberX' and city == @cities[1]")['avg_price_est']
diff = ub_data - ly_data
pos = diff > 0.0
neg = diff < 0.0
axs.bar(diff[pos].index.to_pydatetime(), diff[pos].values, width=0.025, color='r', label="Lower Lyft Prices")
axs.bar(diff[neg].index.to_pydatetime(), diff[neg].values, width=0.025, color='k', label="Lower UberX Prices")
axs.xaxis.set_minor_locator(HourLocator(byhour=range(24), interval=6))
axs.xaxis.set_minor_formatter(DateFormatter('%H'))
axs.xaxis.set_major_locator(WeekdayLocator(byweekday=range(7), interval=1))
axs.xaxis.set_major_formatter(DateFormatter('\n\n%a\n%D'))
axs.set_title("Average Price Difference in Denver Between UberX and Lyft From 4-7-16 to 4-14-16", fontsize=30)
axs.set_ylabel('Average Price Difference', fontsize=20)
axs.set_xlabel('Time', fontsize=20)
axs.tick_params(labelsize=15, which="both")
axs.legend(loc='upper right', fontsize=15);
plt.tight_layout()

# %%
from matplotlib.dates import MonthLocator, WeekdayLocator, DateFormatter, HourLocator

cities = ly['city'].unique().tolist()
fig, axs = plt.subplots(figsize=(20,8))

ly_d = ly.query("ride_type == 'lyft' and city == 'denver'")['avg_est_price']
ub_d = ub.query("display_name == 'uberX' and city == 'denver'")['avg_price_est']

dates = np.unique(ly_d.index.date)
ly_data = ly.query("ride_type == 'lyft' and city == @cities[1]")['avg_est_price']
axs.plot_date(ly_data.index.to_pydatetime(), ly_data.values, 'o-', label='Lyft Prices', color='r')

ub_data = ub.query("display_name == 'uberX' and city == @cities[1]")['avg_price_est']
axs.plot_date(ub_data.index.to_pydatetime(), ub_data.values, 'o-', label='UberX Prices', color='k')

maxy = max([ly_data.max()*1.1,ub_data.max()*1.1])
diff = ub_data - ly_data
# axs.fill_between(ly_data.index, 0, maxy, where=diff >= 0.0 , alpha=0.2, label='Lower Lyft Prices', color='r')

axs.xaxis.set_minor_locator(HourLocator(byhour=range(24), interval=6))
axs.xaxis.set_minor_formatter(DateFormatter('%H'))
axs.xaxis.set_major_locator(WeekdayLocator(byweekday=range(7), interval=1))
axs.xaxis.set_major_formatter(DateFormatter('\n\n%a\n%D'))
# axs.set_title("Average Prices in Denver Between UberX and Lyft From 4-7-16 to 4-14-16", fontsize=30)
# axs.set_ylabel('Average Price Estimate', fontsize=20)
# axs.set_xlabel('Time', fontsize=20)
axs.tick_params(labelsize=15, which="both")
axs.legend(loc='upper right', fontsize=15);
axs.set_ylim([0,maxy])
    
plt.tight_layout()

# %%
forecast = pd.read_csv("../rideshare_app/data/live_forecast_data.csv", parse_dates=['record_time'])
model1 = pd.read_csv("../rideshare_app/data/model1_w_surgemulti_forecast.csv", parse_dates=['record_time'])
model3 = pd.read_csv("../rideshare_app/data/ridgecv_uber_forecast.csv", parse_dates=['record_time'])
model4 = pd.read_csv("../rideshare_app/data/arima_forecast.csv", parse_dates=['record_time'])
model5 = pd.read_csv("../rideshare_app/data/xgboost_model_forecast.csv", parse_dates=['record_time'])

# %%
from matplotlib.dates import MonthLocator, WeekdayLocator, DateFormatter, HourLocator

fig, axs = plt.subplots(figsize=(20,8))
f = forecast.set_index("record_time").query("city == 'ny' and display_name == 'uberx'")['avg_price_est']
m1 = model1.set_index("record_time").query("city_ny == 1 and display_name_uberX == 1")['y_forecast']
m3 = model3.set_index("record_time").query("city_ny == 1 and display_name_uberX == 1")['y_forecast']
m4 = model4.set_index("record_time").query("city_ny == 1 and display_name_uberX == 1")['y_forecast']
m5 = model5.set_index("record_time").query("city_ny == 1 and display_name_uberX == 1")['y_forecast']

axs.plot_date(f.index.to_pydatetime(), f.values, 'o', label="True Values", color='r');
axs.plot_date(m1.index.to_pydatetime(), m1.values, '-', label="Random Forest Regressor", color='b', alpha=0.5);
axs.plot_date(m3.index.to_pydatetime(), m3.values, '-', label="Ridge Regression", color='magenta', alpha=0.5);
axs.plot_date(m4.index.to_pydatetime(), m4.values, '-', label="Multi-variable ARIMA", color='black', alpha=0.5);
axs.plot_date(m5.index.to_pydatetime(), m5.values, '-', label="XGB Regressor", color='g', alpha=0.5);
axs.xaxis.set_minor_locator(HourLocator(byhour=range(24), interval=4))
axs.xaxis.set_minor_formatter(DateFormatter('%H'))
axs.xaxis.set_major_locator(WeekdayLocator(byweekday=range(7), interval=1))
axs.xaxis.set_major_formatter(DateFormatter('\n\n%a\n%D'))
# axs.set_ylabel('Average Price Estimate', fontsize=20)
# axs.set_xlabel('Time', fontsize=20)
axs.tick_params(labelsize=15, which="both")
axs.legend(loc='upper right', fontsize=15)
# axs.set_title("Forecast of New York UberX Prices From 4/11/16 to 4/17/16", fontsize=30)
plt.tight_layout()

# %%
f.head()
# Out:
# record_time
# 2016-04-11 00:00:00    53.938596
# 2016-04-11 01:00:00    64.655172
# 2016-04-11 02:00:00    60.903509
# 2016-04-11 03:00:00    58.868421
# 2016-04-11 04:00:00    65.096491
# Name: avg_price_est, dtype: float64

# %%
df = pd.read_csv("../rideshare_app/data/model1_w_surgemulti_forecast.csv", parse_dates=['record_time'])
short = df.head()

# %%
def highlight_max(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s == s.max()
    return ['background-color: yellow' if v else '' for v in is_max]

# %%
s = short.style.apply(highlight_max)

# %%
s
# Out:
#         <style  type="text/css" >
#
#
#             #T_ecfd8b75_065c_11e6_a613_6003089ed288row0_col0 {
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#             }
#
#             #T_ecfd8b75_065c_11e6_a613_6003089ed288row0_col1 {
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#             }
#
#             #T_ecfd8b75_065c_11e6_a613_6003089ed288row0_col2 {
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#             }
#
#             #T_ecfd8b75_065c_11e6_a613_6003089ed288row0_col4 {
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#             }
#
#             #T_ecfd8b75_065c_11e6_a613_6003089ed288row0_col5 {
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#             }
#
#             #T_ecfd8b75_065c_11e6_a613_6003089ed288row0_col6 {
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#             }
#
#             #T_ecfd8b75_065c_11e6_a613_6003089ed288row0_col7 {
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#             }
#
#             #T_ecfd8b75_065c_11e6_a613_6003089ed288row0_col8 {
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#             }
#
#             #T_ecfd8b75_065c_11e6_a613_6003089ed288row0_col9 {
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#             }
#
#             #T_ecfd8b75_065c_11e6_a613_6003089ed288row0_col10 {
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#             }
#
#             #T_ecfd8b75_065c_11e6_a613_6003089ed288row0_col11 {
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#             }
#
#             #T_ecfd8b75_065c_11e6_a613_6003089ed288row0_col13 {
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#             }
#
#             #T_ecfd8b75_065c_11e6_a613_6003089ed288row0_col14 {
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#             }
#
#             #T_ecfd8b75_065c_11e6_a613_6003089ed288row0_col15 {
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#             }
#
#             #T_ecfd8b75_065c_11e6_a613_6003089ed288row0_col18 {
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#             }
#
#             #T_ecfd8b75_065c_11e6_a613_6003089ed288row0_col19 {
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#             }
#
#             #T_ecfd8b75_065c_11e6_a613_6003089ed288row0_col20 {
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#             }
#
#             #T_ecfd8b75_065c_11e6_a613_6003089ed288row0_col21 {
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#             }
#
#             #T_ecfd8b75_065c_11e6_a613_6003089ed288row0_col23 {
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#             }
#
#             #T_ecfd8b75_065c_11e6_a613_6003089ed288row0_col24 {
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#             }
#
#             #T_ecfd8b75_065c_11e6_a613_6003089ed288row0_col25 {
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#             }
#
#             #T_ecfd8b75_065c_11e6_a613_6003089ed288row0_col26 {
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#             }
#
#             #T_ecfd8b75_065c_11e6_a613_6003089ed288row0_col27 {
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#             }
#
#             #T_ecfd8b75_065c_11e6_a613_6003089ed288row0_col28 {
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;
#
#             }
#
#             #T_ecfd8b75_065c_11e6_a613_6003089ed288row0_col29 {
#
#                 background-color:  yellow;
#
#                 background-color:  yellow;

# %%
a = short.style.highlight_max(axis=0)
a
# Out:
#         <style  type="text/css" >
#
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col1 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col2 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col4 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col5 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col6 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col7 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col8 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col9 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col10 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col11 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col13 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col14 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col15 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col18 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col19 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col20 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col21 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col23 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col24 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col25 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col26 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col27 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col28 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col29 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col30 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col31 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col32 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col33 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col34 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col35 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col36 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col37 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col38 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col39 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col40 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col41 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col42 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col43 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col44 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col45 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col46 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col47 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col48 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col49 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col50 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col51 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row0_col52 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row1_col1 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row1_col2 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row1_col3 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_26126fe3_065d_11e6_92b6_6003089ed288row1_col4 {
#
#                 background-color:  yellow;
#
#             }

# %%
html = a.render()

# %%
html
# Out:
# u'\n        <style  type="text/css" >\n        \n        \n            #T_e63ac305_065e_11e6_9421_6003089ed288row0_col1 {\n            \n                background-color:  yellow;\n            \n                background-color:  yellow;\n            \n                background-color:  yellow;\n            \n            }\n        \n            #T_e63ac305_065e_11e6_9421_6003089ed288row0_col2 {\n            \n                background-color:  yellow;\n            \n                background-color:  yellow;\n            \n                background-color:  yellow;\n            \n            }\n        \n            #T_e63ac305_065e_11e6_9421_6003089ed288row0_col4 {\n            \n                background-color:  yellow;\n            \n                background-color:  yellow;\n            \n                background-color:  yellow;\n            \n            }\n        \n            #T_e63ac305_065e_11e6_9421_6003089ed288row0_col5 {\n            \n                background-color:  yellow;\n            \n                background-color:  yellow;\n            \n                background-color:  yellow;\n            \n            }\n        \n            #T_e63ac305_065e_11e6_9421_6003089ed288row0_col6 {\n            \n                background-color:  yellow;\n            \n                background-color:  yellow;\n            \n                background-color:  yellow;\n            \n            }\n        \n            #T_e63ac305_065e_11e6_9421_6003089ed288row0_col7 {\n            \n                background-color:  yellow;\n            \n                background-color:  yellow;\n            \n                background-color:  yellow;\n            \n            }\n        \n            #T_e63ac305_065e_11e6_9421_6003089ed288row0_col8 {\n            \n                background-color:  yellow;\n            \n                background-color:  yellow;\n            \n                background-color:  yellow;\n            \n            }\n        \n            #T_e63ac305_065e_11e6_9421_6003089ed288row0_col9 {\n            \n                background-color:  yellow;\n            \n                background-color:  yellow;\n            \n                background-color:  yellow;\n            \n            }\n        \n            #T_e63ac305_065e_11e6_9421_6003089ed288row0_col10 {\n            \n                background-color:  yellow;\n            \n                background-color:  yellow;\n            \n                background-color:  yellow;\n            \n            }\n        \n            #T_e63ac305_065e_11e6_9421_6003089ed288row0_col11 {\n            \n                background-color:  yellow;\n            \n                background-color:  yellow;\n            \n                background-color:  yellow;\n            \n            }\n        \n            #T_e63ac305_065e_11e6_9421_6003089ed288row0_col13 {\n            \n                background-color:  yellow;\n            \n                background-color:  yellow;\n            \n                background-color:  yellow;\n            \n            }\n        \n            #T_e63ac305_065e_11e6_9421_6003089ed288row0_col14 {\n            \n                background-color:  yellow;\n            \n                background-color:  yellow;\n            \n                background-color:  yellow;\n            \n            }\n        \n            #T_e63ac305_065e_11e6_9421_6003089ed288row0_col15 {\n            \n                background-color:  yellow;\n            \n                background-color:  yellow;\n            \n                background-color:  yellow;\n            \n            }\n        \n            #T_e63ac305_065e_11e6_9421_6003089ed288row0_col18 {\n            \n                background-color:  yellow;\n            \n                background-color:  yellow;\n            \n                background-color:  yellow;\n            \n            }\n        \n            #T_e63ac305_065e_11e6_9421_6003089ed288row0_c ...

# %%
type(a.data)
# Out:
# pandas.core.frame.DataFrame

# %%
short.style.highlight_max?
