# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("../data/uber_merged_52316.csv", parse_dates=['record_time'])

# %%
df.set_index('record_time', inplace=True)

# %%
df2 = df[['avg_price_est','display_name','city']].query("city == 'sf' and display_name == 'uberX'")[['avg_price_est']].copy()

# %%
hr = df2.resample('H').mean()
hr.head()
# Out:
#                      avg_price_est
# record_time
# 2016-02-15 15:00:00      31.000000
# 2016-02-15 16:00:00      31.500000
# 2016-02-15 17:00:00      35.614035
# 2016-02-15 18:00:00      35.293103
# 2016-02-15 19:00:00      43.545455

# %%
hr.plot(figsize=(10,4));

# %%
pd.ewma()
